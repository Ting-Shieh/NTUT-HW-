# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from celluloid import Camera
from datetime import datetime, timedelta
plt.style.use('seaborn')

dates = [
    datetime(2020, 8, 11),
    datetime(2020, 8, 12),
    datetime(2020, 8, 13),
    datetime(2020, 8, 14),
    datetime(2020, 8, 15),
    datetime(2020, 8, 16),
    datetime(2020, 8, 17),
    datetime(2020, 8, 18),
    datetime(2020, 8, 19),
    datetime(2020, 8, 20),
    datetime(2020, 8, 21),
    datetime(2020, 8, 22),
    datetime(2020, 8, 23),
    datetime(2020, 8, 24)
]

y = [0, 4, 3, 1, 3, 2, 6,0, 4, 3, 1, 3, 2, 6]


fig = plt.figure()
camera = Camera(fig)
for i in range(0,len(y)):
    new_dates = dates[:i]
    z = y[:i]
    plt.plot_date(new_dates,z, linestyle = 'solid',color = 'red')
    plt.tight_layout()
    #plt.show()
    camera.snap()
animation = camera.animate()
# Out:
# <img src="data:image/png;base64,..." width="798.8889100522176">

# %%
import numpy as np 
import matplotlib 
import matplotlib.pyplot as plt 
import matplotlib.animation as animation 
# 指定渲染環境
# %matplotlib notebook 
# %matplotlib inline 
x = np.linspace(0, 2*np.pi, 100) 
y = np.sin(x) 
fig = plt.figure(tight_layout=True) 
plt.plot(x,y) 
plt.grid(ls="--") 
plt.show()

# %%
# def update_points(num): 
#     ''' 更新數據點 ''' 
#     point_ani.set_data(x[num], y[num]) 
#     return point_ani, 


def update_points(num): 
    point_ani.set_data(x[num], y[num]) 
    if num%5==0: 
        point_ani.set_marker("*") 
        point_ani.set_markersize(12) 
    else: 
        point_ani.set_marker("o")
        point_ani.set_markersize(8) 
        text_pt.set_position((x[num], y[num])) 
        text_pt.set_text("x=%.3f, y=%.3f"%(x[num], y[num]))
    return point_ani,text_pt,
x = np.linspace(0, 2*np.pi, 100) 
y = np.sin(x) 
fig = plt.figure(tight_layout=True) 
plt.plot(x,y) 
point_ani, = plt.plot(x[0], y[0], "ro") 
plt.grid(ls="--") 
# 開始製作動畫 
ani = animation.FuncAnimation(fig, update_points, np.arange(0, 100), interval=100, blit=True) 
# ani.save('sin_test2.gif', writer='imagemagick', fps=10) plt.show()
# Out:
# Traceback (most recent call last):
#   File "C:\Users\user1\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 196, in process
#     func(*args, **kwargs)
#   File "C:\Users\user1\anaconda3\lib\site-packages\matplotlib\animation.py", line 951, in _start
#     self._init_draw()
#   File "C:\Users\user1\anaconda3\lib\site-packages\matplotlib\animation.py", line 1743, in _init_draw
#     self._draw_frame(next(self.new_frame_seq()))
#   File "C:\Users\user1\anaconda3\lib\site-packages\matplotlib\animation.py", line 1766, in _draw_frame
#     self._drawn_artists = self._func(framedata, *self._args)
#   File "<ipython-input-8-2b1ff6b8de1c>", line 17, in update_points
#     return point_ani,text_pt,
# NameError: name 'text_pt' is not defined

# %%
def update_points(num): 
    point_ani.set_data(x[num], y[num]) 
    if num%5==0: 
        point_ani.set_marker("*") 
        point_ani.set_markersize(12) 
    else: 
        point_ani.set_marker("o")
        point_ani.set_markersize(8) 
        text_pt.set_position((x[num], y[num])) 
        text_pt.set_text("x=%.3f, y=%.3f"%(x[num], y[num]))
    return point_ani,text_pt,

# %%
# !pip install moviepy

# %%
# 創建 figure
fig, ax = plt.subplots()
fig = plt.figure(figsize=(6, 8))

# 成員函數
fig.set_tight_layout(True)
fig.get_dpi()
fig.get_size_inches()
# Out:
# array([6., 8.])

# %%
# %matplotlib notebook 
# %matplotlib inline 
from moviepy.video.io.bindings import mplfig_to_npimage
import moviepy.editor as mpy

f = plt.figure(figsize=(8, 8))

# 接受一個時間參數，
def make_frame_mpl(t):
    ...
    return mplfig_to_npimage(f)
                # 所有的圖像都在同一個figure上

animation = mpy.VideoClip(make_frame_mpl, duration=5)
animation.write_gif("animation-94a2c1ff.gif", fps=20)
        # 這樣其實就可以做一個動態圖出來了；
# Out:
# t:   8%|█████▌                                                               | 8/100 [00:00<00:01, 71.39it/s, now=None]
# MoviePy - Building file animation-94a2c1ff.gif with imageio.

# %%
# %matplotlib notebook 
# %matplotlib inline 
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np
import seaborn

fig, ax = plt.subplots()

x = np.arange(0, 20, .01)
ax.scatter(x, x+np.random.normal(0, 3, len(x)))
line, = ax.plot(x, x-5, 'r-', lw=2)


# i => ith frame
def update(i):
    line.set_ydata(x-5+i)
    ax.set_xlabel('frame {0}'.format(i))
    return line, ax



animation = FuncAnimation(fig, update, frames=np.arange(0, 20), interval=200)
# 200ms 的間隔，相當於 5fps，一秒 5 幀
plt.show()

# %%
animation.save('line.gif', dpi=80, writer='imagemagick')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b87162370355> in <module>
# ----> 1 animation.save('line.gif', dpi=80, writer='imagemagick')
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1100                                          metadata=metadata)
#    1101             else:
# -> 1102                 alt_writer = next(writers, None)
#    1103                 if alt_writer is None:
#    1104                     raise ValueError("Cannot save animation: no writers are "
#
# TypeError: 'MovieWriterRegistry' object is not an iterator

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-4ba56342ecc6> in <module>
#      37         curr_country = data.country[cont_ind]
#      38         y_axis = np.array(data.iloc[cont_ind,1:f+1])
# ---> 39         curr_data.append(go.Scatter(x = x_axis, y = y_axis,mode = "lines", name = curr_country))
#      40         title_names.append(curr_country + ": " + str(y_axis[f-1]/1000) + "K Dollar. ")
#      41     title = start + " " + " ".join(title_names)
#
# ~\anaconda3\lib\site-packages\plotly\graph_objs\__init__.py in __init__(self, arg, cliponaxis, connectgaps, customdata, customdatasrc, dx, dy, error_x, error_y, fill, fillcolor, groupnorm, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legendgroup, line, marker, meta, metasrc, mode, name, opacity, orientation, r, rsrc, selected, selectedpoints, showlegend, stackgaps, stackgroup, stream, t, text, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, tsrc, uid, uirevision, unselected, visible, x, x0, xaxis, xcalendar, xsrc, y, y0, yaxis, ycalendar, ysrc, **kwargs)
#   37959         self._validators["visible"] = v_scatter.VisibleValidator()
#   37960         self._validators["x"] = v_scatter.XValidator()
# > 37961         self._validators["x0"] = v_scatter.X0Validator()
#   37962         self._validators["xaxis"] = v_scatter.XAxisValidator()
#   37963         self._validators["xcalendar"] = v_scatter.XcalendarValidator()
#
# ~\anaconda3\lib\site-packages\plotly\validators\scatter\__init__.py in __init__(self, plotly_name, parent_name, **kwargs)
#     162 class X0Validator(_plotly_utils.basevalidators.AnyValidator):
#     163     def __init__(self, plotly_name="x0", parent_name="scatter", **kwargs):
# --> 164         super(X0Validator, self).__init__(
#     165             plotly_name=plotly_name,
#     166             parent_name=parent_name,
#
# KeyboardInterrupt:
